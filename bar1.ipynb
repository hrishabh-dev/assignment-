# %%
import matplotlib.pyplot as plt 
import numpy as np
state=['PUNJAB','HARYANA','UP','MP','KERALA','RAJASTHAN']
cl=['green','red','blue','pink','black','brown']
area=[220,120,100,40,80,30]
plt.bar(state,area,color=cl,edgecolor='brown')
plt.xlabel('state')
plt.ylabel('Area(Lac hectares)')
plt.title('Wheat Cultivation')
plt.show()
